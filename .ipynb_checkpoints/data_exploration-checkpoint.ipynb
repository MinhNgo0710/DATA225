# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## EV charger file

# %%
ev_charger = pd.read_excel('/Users/minhngo/Documents/GitHub/DATA225/raw_data/EV_Chargers_Last_updated_03-20-2023.xlsx', 
                           engine='openpyxl')
ev_charger
# Out:
#     Unnamed: 0                                         Unnamed: 1
# 0          NaN  California Energy Commission Zero Emission Veh...
# 1          NaN                         Data as of January 3, 2023
# 2          NaN                                                NaN
# 3          NaN           Please cite use of these data and images
# 4          NaN  California Energy Commission (2023). Californi...
# 5          NaN  Statistics. Data last updated [insert date las...
# 6          NaN                 http://www.energy.ca.gov/zevstats.
# 7          NaN                                                NaN
# 8          NaN  Please submit questions and comments to: media...
# 9          NaN                                                NaN
# 10         NaN                               Notes about the Data
# 11         NaN                                                NaN
# 12         NaN  Public charger counts are obtained from the Al...
# ...
